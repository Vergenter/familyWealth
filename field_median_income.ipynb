# %% [markdown]
# # Data wrangling on earnings split

# %% [markdown]
# ## Read data and correct labeles

# %%
from pandas import merge as pd_merge,pivot,read_csv,set_option
filename = 'dataset//earnings_split/EAR_4MTH_SEX_ECO_CUR_NB_A-filtered-2021-03-21.csv'
df_field_incomes_columns_csv = ["ref_area.label","classif1.label","classif2.label","time","obs_value"]
df_field_incomes_columns_names = ["Country","Field","Currency","Year","Income"]
df_field_incomes = read_csv(filename,usecols=df_field_incomes_columns_csv)
# take only rows in dollars and drop currency label
df_field_incomes = df_field_incomes[(df_field_incomes["classif2.label"]=="Currency: U.S. dollars") & (df_field_incomes["time"]>2009)].drop("classif2.label", axis=1)
# rename fields
df_field_incomes = df_field_incomes.rename(columns={k:v for k,v in zip(df_field_incomes_columns_csv,df_field_incomes_columns_names)})
# take only one type of total value
df_field_incomes = df_field_incomes[(df_field_incomes["Field"]=="Economic activity (Aggregate): Total") | (~df_field_incomes.Field.str.endswith('Total')) ]
# keep possibly cut too much
df_field_incomes["Field"] = list(map(lambda text: text.split(":")[1][1:],df_field_incomes["Field"]))
df_field_incomes.head(25)
# Out:
#         Country                                              Field  Year  \
# 5         Aruba               A. Agriculture, hunting and forestry  2010
# 8         Aruba                                         B. Fishing  2010
# 11        Aruba                            C. Mining and quarrying  2010
# 14        Aruba                                   D. Manufacturing  2010
# 17        Aruba               E. Electricity, gas and water supply  2010
# 20        Aruba                                    F. Construction  2010
# 23        Aruba  G. Wholesale and retail trade; repair of motor...  2010
# 26        Aruba                          H. Hotels and restaurants  2010
# 29        Aruba           I. Transport, storage and communications  2010
# 32        Aruba                        J. Financial intermediation  2010
# 35        Aruba    K. Real estate, renting and business activities  2010
# 38        Aruba  L. Public administration and defence; compulso...  2010
# 41        Aruba                                       M. Education  2010
# 44        Aruba                          N. Health and social work  2010
# 47        Aruba  O. Other community, social and personal servic...  2010
# 50        Aruba  P. Activities of private households as employe...  2010
# 53        Aruba       Q. Extraterritorial organizations and bodies  2010
# 56        Aruba                        X. Not elsewhere classified  2010
# 59        Aruba                                              Total  2010
# 65  Afghanistan               A. Agriculture, hunting and forestry  2014
# 68  Afghanistan                            C. Mining and quarrying  2014
# 71  Afghanistan                                   D. Manufacturing  2014
# 74  Afghanistan               E. Electricity, gas and water supply  2014
# 77  Afghanistan                                    F. Construction  2014
# 80  Afghanistan  G. Wholesale and retail trade; repair of motor...  2014
#
#      Income
# 5   1221.79
# 8   1022.35
# 11  1463.13
# 14  2031.28
# 17  3022.35
# 20  1390.50
# 23  1320.67
# 26  1342.46
# 29  1872.07
# 32  2451.96
# 35  1558.10
# 38  2411.73
# 41  2586.03
# 44  1945.25
# 47  1490.50
# 50   537.99
# 53  2857.54
# 56  1196.09
# 59  1683.24
# 65    92.87
# 68   129.97
# 71    75.33
# 74   166.03
# 77   113.95
# 80   156.50

# %% [markdown]
# ## Transpose data for more readable results

# %%
grupedByYear = [ddd.rename(columns={"Income":str(int(Year))}).drop("Year", axis=1) for Year,ddd in df_field_incomes.groupby("Year")]
from functools import reduce
from pandas import merge as pd_merge
merged_pd = reduce(lambda a,b: pd_merge(a,b, on=["Field", "Country"],how="left"),grupedByYear[:-1])
merged_pd.head()
# Out:
#   Country                                 Field     2010  2011  2012  2013  \
# 0   Aruba  A. Agriculture, hunting and forestry  1221.79   NaN   NaN   NaN
# 1   Aruba                            B. Fishing  1022.35   NaN   NaN   NaN
# 2   Aruba               C. Mining and quarrying  1463.13   NaN   NaN   NaN
# 3   Aruba                      D. Manufacturing  2031.28   NaN   NaN   NaN
# 4   Aruba  E. Electricity, gas and water supply  3022.35   NaN   NaN   NaN
#
#    2014  2015  2016  2017  2018  2019
# 0   NaN   NaN   NaN   NaN   NaN   NaN
# 1   NaN   NaN   NaN   NaN   NaN   NaN
# 2   NaN   NaN   NaN   NaN   NaN   NaN
# 3   NaN   NaN   NaN   NaN   NaN   NaN
# 4   NaN   NaN   NaN   NaN   NaN   NaN

# %% [markdown]
# ## Remove rows with too much nulls or replace them with mean value between previous and last year

# %%
import numpy as np
def removeNull(df):
    for index, row in df.iterrows():
        null_row = row.isnull()
        nulls_in_row = null_row.sum()
        if nulls_in_row > 1 or np.isnan(row['2010']) or np.isnan(row['2019']):
            df.drop(index, inplace=True)
        elif nulls_in_row==1:
            null_index = np.where(null_row)[0][0]
            df.at[index,merged_pd.columns.values[null_index]] = (row[null_index-1]+row[null_index+1])/2
removeNull(merged_pd)
print(merged_pd.shape)
merged_pd.head()
# Out:
# (531, 12)
#     Country                                              Field    2010  \
# 54  Armenia               A. Agriculture; forestry and fishing  188.86
# 55  Armenia                            B. Mining and quarrying  580.43
# 56  Armenia                                   C. Manufacturing  268.97
# 57  Armenia  D. Electricity; gas, steam and air conditionin...  400.84
# 58  Armenia  E. Water supply; sewerage, waste management an...  268.06
#
#       2011    2012    2013    2014    2015    2016    2017    2018    2019
# 54  188.18  208.17  224.69  240.18  180.14  159.63  195.87  192.78  210.22
# 55  638.04  642.48  773.98  795.76  353.03  322.89  348.52  384.98  430.47
# 56  272.61  276.22  332.28  343.75  212.04  215.81  220.56  219.63  235.63
# 57  408.57  383.22  472.16  541.54  244.74  235.88  267.28  233.56  265.93
# 58  301.18  276.06  340.92  368.02  185.43  174.76  210.34  207.37  213.12

# %% [markdown]
# ## Analyze fields

# %%
merged_pd.Field.value_counts().plot.barh(figsize=(24,12),title="Histogram of fields data")
# Out:
# <AxesSubplot:title={'center':'Histogram of fields data'}>

# %%
merged_pd.Field.value_counts()
# Out:
# Total                                                                                                                            38
# F. Construction                                                                                                                  33
# C. Manufacturing                                                                                                                 21
# P. Education                                                                                                                     21
# G. Wholesale and retail trade; repair of motor vehicles and motorcycles                                                          21
# H. Transportation and storage                                                                                                    21
# K. Financial and insurance activities                                                                                            21
# J. Information and communication                                                                                                 20
# I. Accommodation and food service activities                                                                                     20
# L. Real estate activities                                                                                                        20
# Q. Human health and social work activities                                                                                       20
# B. Mining and quarrying                                                                                                          20
# S. Other service activities                                                                                                      19
# M. Professional, scientific and technical activities                                                                             19
# R. Arts, entertainment and recreation                                                                                            19
# D. Electricity; gas, steam and air conditioning supply                                                                           19
# E. Water supply; sewerage, waste management and remediation activities                                                           18
# N. Administrative and support service activities                                                                                 18
# O. Public administration and defence; compulsory social security                                                                 16
# Agriculture                                                                                                                      15
# Manufacturing                                                                                                                    15
# Construction                                                                                                                     15
# Mining and quarrying; Electricity, gas and water supply                                                                          14
# A. Agriculture; forestry and fishing                                                                                             14
# Public Administration, Community, Social and other Services and Activities                                                       14
# Trade, Transportation, Accommodation and Food, and Business and Administrative Services                                          14
# T. Activities of households as employers; undifferentiated goods- and services-producing activities of households for own use     6
# U. Activities of extraterritorial organizations and bodies                                                                        4
# O. Other community, social and personal service activities                                                                        1
# N. Health and social work                                                                                                         1
# I. Transport, storage and communications                                                                                          1
# G. Wholesale and retail trade; repair of motor vehicles, motorcycles and personal and household goods                             1
# H. Hotels and restaurants                                                                                                         1
# L. Public administration and defence; compulsory social security                                                                  1
# A. Agriculture, hunting and forestry                                                                                              1
# Q. Extraterritorial organizations and bodies                                                                                      1
# M. Education                                                                                                                      1
# J. Financial intermediation                                                                                                       1
# B. Fishing                                                                                                                        1
# C. Mining and quarrying                                                                                                           1
# E. Electricity, gas and water supply                                                                                              1
# P. Activities of private households as employers and undifferentiated production activities of private households                 1
# D. Manufacturing                                                                                                                  1
# K. Real estate, renting and business activities                                                                                   1
# Name: Field, dtype: int64

# %% [markdown]
# ## Remove rows with fields that would not be analyzed

# %%
to_drop = [
"Construction",
"Manufacturing",
"Agriculture",
"Trade, Transportation, Accommodation and Food, and Business and Administrative Services",
"Public Administration, Community, Social and other Services and Activities  ",
"Mining and quarrying; Electricity, gas and water supply"
]
to_drop_statistically_different = [
    "B. Fishing",
    "E. Electricity, gas and water supply",
    "P. Activities of private households as employers and undifferentiated production activities of private households",
    "M. Education",
    "O. Other community, social and personal service activities",
    "Q. Extraterritorial organizations and bodies",
    "D. Manufacturing",
    "J. Financial intermediation",
    "G. Wholesale and retail trade; repair of motor vehicles, motorcycles and personal and household goods",
    "C. Mining and quarrying",
    "A. Agriculture, hunting and forestry",
    "K. Real estate, renting and business activities",
    "H. Hotels and restaurants",
    "I. Transport, storage and communications",
    "L. Public administration and defence; compulsory social security",
    "N. Health and social work"
]
merged_pd = merged_pd[~merged_pd.Field.isin(to_drop)]
merged_pd = merged_pd[~merged_pd.Field.isin(to_drop_statistically_different)]
merged_pd.Field.value_counts().plot.barh(figsize=(24,12),title="Histogram of fields data after clean up" )
# Out:
# <AxesSubplot:title={'center':'Histogram of fields data after clean up'}>

# %% [markdown]
# ## Analyze total "field" to narrow down possible problems

# %% [markdown]
# ### Show all values in table

# %%
merged_total = merged_pd[merged_pd.Field.str.endswith('Total')].drop("Field", axis=1).set_index('Country')
print(merged_total.shape)
merged_total.head(50)
# Out:
# (38, 10)
#                            2010     2011     2012     2013      2014     2015  \
# Country
# Armenia                  274.72   290.18   281.67   357.70   381.280   209.93
# Austria                 3379.25  3365.75  3182.42  3337.56  3727.770  2883.62
# Azerbaijan               413.01   461.20   507.10   541.85   566.710   455.71
# Bosnia and Herzegovina   471.49   501.31   458.74   493.00   507.310   418.74
# Canada                  3435.69  3662.62  3742.07  3708.02  3520.010  3125.56
# Colombia                 452.02   480.80   510.82   524.67   519.660   381.16
# Costa Rica               713.44   774.43   865.63   948.05   904.630   987.93
# Japan                   2794.30  2712.94  2772.970   235.22
# Korea, Republic of      2887.71  3048.41  3264.880  3192.15
# Moldova, Republic of     250.85    25.17    31.090   411.63
# Mongolia                 402.70   387.14   405.620   422.11
# Mauritius                568.75   615.56   649.320   578.62
# Norway                  5468.54  5356.84  5608.360  5373.86
# Panama                   803.12   854.87   870.470   895.41
# Peru                     655.56   699.59   716.470   474.96
# Philippines              257.23   250.89   256.110   283.67
# Poland                  1026.49  1133.46   105.900   106.75
# Paraguay                 371.19   387.19   420.100   391.37
# Russian Federation       547.44   661.76   676.345   690.93
# Singapore               2935.84  3064.61  3289.490  3344.92
# El Salvador              296.92   318.55   332.110   347.29
# Slovakia                1155.61  1244.33  1387.950  1412.78
# Ukraine                  202.85   267.10   325.910   406.14
# Uruguay                  860.34  1055.04  1044.470   989.19
# United States           3834.60  3955.18  4088.470  4233.08
# Viet Nam                 250.42   240.13   255.550   288.79

# %% [markdown]
# ### Show diffrence of values to look for anomalies

# %%
merged_total.T.diff().plot(figsize=(24,12),title="title",legend=True,ylabel="value difference",xlabel="year")
# Out:
# <AxesSubplot:title={'center':'title'}, xlabel='year', ylabel='value difference'>

# %% [markdown]
# ### Show percent change of values to look for anomalies

# %%
merged_total.T.pct_change().plot(figsize=(24,12),title="title",legend=True)
# Out:
# <AxesSubplot:title={'center':'title'}>

# %% [markdown]
# ### Found anomalies:
#
# * Costa Rica 2018
#
# * Japan 2019
#
# * Moldova, Republic of 2017/2018
#
# * Poland 2018/ 2019

# %% [markdown]
# ### Show anomalies and check if they are same for all fields

# %%
from IPython.display import display
display(merged_pd[merged_pd.Country == "Poland"].head())
display(merged_pd[merged_pd.Country == "Japan"].head())
display(merged_pd[merged_pd.Country == "Moldova, Republic of"].head())
display(merged_pd[merged_pd.Country == "Costa Rica"].head())
# Out:
#      Country                                              Field     2010  \
# 1275  Poland               A. Agriculture; forestry and fishing  1095.90
# 1276  Poland                            B. Mining and quarrying  1929.43
# 1277  Poland                                   C. Manufacturing   967.46
# 1278  Poland  D. Electricity; gas, steam and air conditionin...  1741.81
# 1279  Poland  E. Water supply; sewerage, waste management an...  1070.41
#
#          2011     2012     2013     2014     2015     2016     2017    2018  \
# 1275  1231.45  1210.21  1256.24  1322.80  1153.54  1139.70  1216.49  112.96
# 1276  2239.87  1941.39  2154.29  2159.02  1813.88  1733.10  1858.10  179.35
# 1277  1045.59   996.16  1071.54  1121.04   973.42   971.94  1086.95  101.68
# 1278  1896.80  1804.67  1972.57  2014.13  1736.82  1716.16  1856.16  171.28
# 1279  1133.54  1065.38  1127.89  1168.13  1014.80  1005.19  1088.48   99.79
#
#         2019
# 1275  111.64
# 1276  180.22
# 1277  102.30
# 1278  169.05
# 1279   99.41
#     Country                                              Field     2010  \
# 770   Japan                            B. Mining and quarrying  3556.62
# 772   Japan                                    F. Construction  3512.19
# 773   Japan  G. Wholesale and retail trade; repair of motor...  3391.44
# 774   Japan                      H. Transportation and storage  2979.04
# 775   Japan       I. Accommodation and food service activities  2697.66
#
#         2011     2012     2013     2014     2015     2016     2017     2018  \
# 770  3792.90  3912.75  3195.84  2914.73  2551.96  2985.49  2864.50  3016.58
# 772  3925.72  3898.96  3248.10  3017.61  2709.76  3075.57  2946.52  3031.07
# 773  3621.24  3714.73  3005.26  2880.75  2520.57  2830.15  2745.93  2800.14
# 774  3230.29  3288.61  2648.68  2527.73  2209.94  2546.12  2449.94  2542.94
# 775  2967.16  2947.72  2383.30  2285.15  1990.18  2219.81  2158.41  2221.45
#
#        2019
# 770  250.21
# 772  254.41
# 773  241.34
# 774  213.90
# 775  189.43
#                    Country            Field    2010    2011     2012    2013  \
# 1009  Moldova, Republic of  F. Construction  262.59  246.13  274.905  303.68
# 1019  Moldova, Republic of            Total  240.25  259.14  287.140  291.91
#
#         2014    2015    2016   2017   2018    2019
# 1009  296.79  232.65  243.09  24.98  30.74  407.16
# 1019  291.38  241.17  250.85  25.17  31.09  411.63
#         Country  Field    2010    2011    2012    2013    2014    2015  \
# 286  Costa Rica  Total  713.44  774.43  865.63  948.05  904.63  987.93
#
#        2016    2017   2018    2019
# 286  935.95  911.54  52.72  929.38

# %% [markdown]
# ### Fix anomalies

# %%
for index in merged_pd.index:
    if merged_pd.loc[index,'Country']=='Poland':
        if merged_pd.loc[index,'2018']<200:
            merged_pd.loc[index,'2018'] = merged_pd.loc[index,'2018']*10
        if merged_pd.loc[index,'2019']<200:
            merged_pd.loc[index,'2019'] = merged_pd.loc[index,'2019']*10
    elif merged_pd.loc[index,'Country']=='Japan':
        if merged_pd.loc[index,'2019']<300:
            merged_pd.loc[index,'2019'] = merged_pd.loc[index,'2019']*10
    elif merged_pd.loc[index,'Country']=='Moldova, Republic of':
        if merged_pd.loc[index,'2017']<50:
            merged_pd.loc[index,'2017'] = merged_pd.loc[index,'2017']*10
        if merged_pd.loc[index,'2018']<50:
            merged_pd.loc[index,'2018'] = merged_pd.loc[index,'2018']*10
    elif merged_pd.loc[index,'Country']=='Costa Rica':
        if merged_pd.loc[index,'2018']<100:
            merged_pd.loc[index,'2018'] = merged_pd.loc[index,'2018']*10
display(merged_pd[merged_pd.Country == "Poland"].head())
display(merged_pd[merged_pd.Country == "Japan"].head())
display(merged_pd[merged_pd.Country == "Moldova, Republic of"].head())
display(merged_pd[merged_pd.Country == "Costa Rica"].head())
# Out:
#      Country                                              Field     2010  \
# 1275  Poland               A. Agriculture; forestry and fishing  1095.90
# 1276  Poland                            B. Mining and quarrying  1929.43
# 1277  Poland                                   C. Manufacturing   967.46
# 1278  Poland  D. Electricity; gas, steam and air conditionin...  1741.81
# 1279  Poland  E. Water supply; sewerage, waste management an...  1070.41
#
#          2011     2012     2013     2014     2015     2016     2017    2018  \
# 1275  1231.45  1210.21  1256.24  1322.80  1153.54  1139.70  1216.49  1129.6
# 1276  2239.87  1941.39  2154.29  2159.02  1813.88  1733.10  1858.10  1793.5
# 1277  1045.59   996.16  1071.54  1121.04   973.42   971.94  1086.95  1016.8
# 1278  1896.80  1804.67  1972.57  2014.13  1736.82  1716.16  1856.16  1712.8
# 1279  1133.54  1065.38  1127.89  1168.13  1014.80  1005.19  1088.48   997.9
#
#         2019
# 1275  1116.4
# 1276  1802.2
# 1277  1023.0
# 1278  1690.5
# 1279   994.1
#     Country                                              Field     2010  \
# 770   Japan                            B. Mining and quarrying  3556.62
# 772   Japan                                    F. Construction  3512.19
# 773   Japan  G. Wholesale and retail trade; repair of motor...  3391.44
# 774   Japan                      H. Transportation and storage  2979.04
# 775   Japan       I. Accommodation and food service activities  2697.66
#
#         2011     2012     2013     2014     2015     2016     2017     2018  \
# 770  3792.90  3912.75  3195.84  2914.73  2551.96  2985.49  2864.50  3016.58
# 772  3925.72  3898.96  3248.10  3017.61  2709.76  3075.57  2946.52  3031.07
# 773  3621.24  3714.73  3005.26  2880.75  2520.57  2830.15  2745.93  2800.14
# 774  3230.29  3288.61  2648.68  2527.73  2209.94  2546.12  2449.94  2542.94
# 775  2967.16  2947.72  2383.30  2285.15  1990.18  2219.81  2158.41  2221.45
#
#        2019
# 770  2502.1
# 772  2544.1
# 773  2413.4
# 774  2139.0
# 775  1894.3
#                    Country            Field    2010    2011     2012    2013  \
# 1009  Moldova, Republic of  F. Construction  262.59  246.13  274.905  303.68
# 1019  Moldova, Republic of            Total  240.25  259.14  287.140  291.91
#
#         2014    2015    2016   2017   2018    2019
# 1009  296.79  232.65  243.09  249.8  307.4  407.16
# 1019  291.38  241.17  250.85  251.7  310.9  411.63
#         Country  Field    2010    2011    2012    2013    2014    2015  \
# 286  Costa Rica  Total  713.44  774.43  865.63  948.05  904.63  987.93
#
#        2016    2017   2018    2019
# 286  935.95  911.54  527.2  929.38

# %% [markdown]
# ## Check plots for new anomalies

# %%
merged_total = merged_pd[merged_pd.Field.str.endswith('Total')].drop("Field", axis=1).set_index('Country')
merged_total.T.diff().plot(figsize=(24,12),title="title",legend=True)
# Out:
# <AxesSubplot:title={'center':'title'}>

# %%
merged_total.T.pct_change().plot(figsize=(24,12),title="title",legend=True)
# Out:
# <AxesSubplot:title={'center':'title'}>

# %% [markdown]
# ### Conclusions
#
# * values that rapidly change on diffrence plot are for highly developed countries, where high value change is relativly low percent change
#
# * values on percent change plot are in reasonable boundaries

# %% [markdown]
# ## Analyze fields data

# %% [markdown]
# ### Prepare table

# %%
merged_pd = merged_pd.set_index(['Country', 'Field'])
merged_pd.head()
# Out:
#                                                               2010    2011  \
# Country Field
# Armenia A. Agriculture; forestry and fishing                188.86  188.18
#         B. Mining and quarrying                             580.43  638.04
#         C. Manufacturing                                    268.97  272.61
#         D. Electricity; gas, steam and air conditioning...  400.84  408.57
#         E. Water supply; sewerage, waste management and...  268.06  301.18
#
#                                                               2012    2013  \
# Country Field
# Armenia A. Agriculture; forestry and fishing                208.17  224.69
#         B. Mining and quarrying                             642.48  773.98
#         C. Manufacturing                                    276.22  332.28
#         D. Electricity; gas, steam and air conditioning...  383.22  472.16
#         E. Water supply; sewerage, waste management and...  276.06  340.92
#
#                                                               2014    2015  \
# Country Field
# Armenia A. Agriculture; forestry and fishing                240.18  180.14
#         B. Mining and quarrying                             795.76  353.03
#         C. Manufacturing                                    343.75  212.04
#         D. Electricity; gas, steam and air conditioning...  541.54  244.74
#         E. Water supply; sewerage, waste management and...  368.02  185.43
#
#                                                               2016    2017  \
# Country Field
# Armenia A. Agriculture; forestry and fishing                159.63  195.87
#         B. Mining and quarrying                             322.89  348.52
#         C. Manufacturing                                    215.81  220.56
#         D. Electricity; gas, steam and air conditioning...  235.88  267.28
#         E. Water supply; sewerage, waste management and...  174.76  210.34
#
#                                                               2018    2019
# Country Field
# Armenia A. Agriculture; forestry and fishing                192.78  210.22
#         B. Mining and quarrying                             384.98  430.47
#         C. Manufacturing                                    219.63  235.63
#         D. Electricity; gas, steam and air conditioning...  233.56  265.93
#         E. Water supply; sewerage, waste management and...  207.37  213.12

# %% [markdown]
# ### Analyze plots for anomalies

# %%
merged_pd.T.diff().plot(figsize=(24,12),title="title",legend=False)
# Out:
# <AxesSubplot:title={'center':'title'}>

# %%
merged_pd.T.pct_change().plot(figsize=(24,12),title="title",legend=False)
# Out:
# <AxesSubplot:title={'center':'title'}>

# %% [markdown]
# ### Check high percent changes

# %%
set_option('display.max_rows', None)
data = merged_pd.T.pct_change().max().nlargest(10)
display(data)
# Out:
# Country    Field
# Egypt      K. Financial and insurance activities                                     4.431345
# Greece     L. Real estate activities                                                 3.827899
# Egypt      E. Water supply; sewerage, waste management and remediation activities    2.056648
#            Q. Human health and social work activities                                1.819042
#            H. Transportation and storage                                             1.584007
#            Total                                                                     1.519102
# Greece     D. Electricity; gas, steam and air conditioning supply                    1.339906
# Egypt      D. Electricity; gas, steam and air conditioning supply                    1.275722
# Greece     E. Water supply; sewerage, waste management and remediation activities    1.220636
# Guatemala  B. Mining and quarrying                                                   1.208796
# dtype: float64

# %%
merged_pd[merged_pd.index.isin(data.index)]
# Out:
#                                                                  2010  \
# Country   Field
# Egypt     D. Electricity; gas, steam and air conditioning...   172.13
#           E. Water supply; sewerage, waste management and...   114.92
#           H. Transportation and storage                        184.21
#           K. Financial and insurance activities                193.65
#           Q. Human health and social work activities           112.46
#           Total                                                142.92
# Greece    D. Electricity; gas, steam and air conditioning...  4214.45
#           E. Water supply; sewerage, waste management and...  3076.99
#           L. Real estate activities                           2166.22
# Guatemala B. Mining and quarrying                              330.34
#
#                                                                  2011  \
# Country   Field
# Egypt     D. Electricity; gas, steam and air conditioning...   391.72
#           E. Water supply; sewerage, waste management and...   351.27
#           H. Transportation and storage                        476.00
#           K. Financial and insurance activities               1051.78
#           Q. Human health and social work activities           306.09
#           Total                                                360.03
# Greece    D. Electricity; gas, steam and air conditioning...  1878.79
#           E. Water supply; sewerage, waste management and...  1473.45
#           L. Real estate activities                           1125.13
# Guatemala B. Mining and quarrying                              609.11
#
#                                                                  2012  \
# Country   Field
# Egypt     D. Electricity; gas, steam and air conditioning...   553.50
#           E. Water supply; sewerage, waste management and...   496.03
#           H. Transportation and storage                        607.66
#           K. Financial and insurance activities               1337.50
#           Q. Human health and social work activities           276.75
#           Total                                                423.38
# Greece    D. Electricity; gas, steam and air conditioning...  1533.82
#           E. Water supply; sewerage, waste management and...  1244.12
